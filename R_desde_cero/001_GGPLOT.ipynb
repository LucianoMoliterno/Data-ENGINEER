# %% [markdown]
# Tidyverse es una colección de paquetes de R diseñados para la ciencia de datos.
#
# # Ggplot2
#
# Es un paquete que sirve para la creación de gráficos

# %%
install.packages("tidyverse")
library(tidyverse)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘textshaping’, ‘conflicted’, ‘ragg’
#
#
# Warning message in install.packages("tidyverse"):
# “installation of package ‘textshaping’ had non-zero exit status”
# Warning message in install.packages("tidyverse"):
# “installation of package ‘ragg’ had non-zero exit status”
# Warning message in install.packages("tidyverse"):
# “installation of package ‘tidyverse’ had non-zero exit status”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.2     ✔ purrr   1.0.1
# ✔ tibble  3.2.1     ✔ dplyr   1.1.2
# ✔ tidyr   1.3.0     ✔ stringr 1.5.0
# ✔ readr   2.1.4     ✔ forcats 1.0.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# Utilizaremos el paquete **palmerpenguins**, el cual incluye el conjunto de datos `oenguins` el cual contiene distintos datos de los pingüinos que se encuentran en las islas del archipielago Palmer.

# %%
install.packages("palmerpenguins")
library(palmerpenguins)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# - ¿Los pingüinos con aletas más largas pesan más o menos que los pingüinos con aletas más cortas?
# - ¿Cómo es la relación entre la longitud de las aletas y la masa corporal? ¿Es positiva? ¿negativa? ¿lineal? ¿No lineal?
# - ¿Varía la relación según la especie del pingüino?
#
# ## DataFrame
#
# Un dataframe es una colección rectangular de variables (columnas) y observaciones (filas) `penguins` contiene 344 observaciones.
#
# Definir algunos terminos
# - Variable: Un cantidad, cualidad, o propiedad que se puede medir
# - Valor: El estado de una variable cuando la mides. El valor de la variable puede cambiar de medición en medición
# - Observación: Conjunto de mediciones realizadas en condiciones similares. Una observación contendrá varios valores, cada uno asociado a una variable diferente.
# - Datos tabulados: Un conjunto de valores, cada uno asociado con una variable y una observación.
#
# En este contexto, una variable refiere a un atributo de todos los pingüinos, y una observación refiere a todos los atributos de un solo pingüino.

# %%
View(penguins)
# Out:
#     species   island    bill_length_mm bill_depth_mm flipper_length_mm
# 1   Adelie    Torgersen 39.1           18.7          181
# 2   Adelie    Torgersen 39.5           17.4          186
# 3   Adelie    Torgersen 40.3           18.0          195
# 4   Adelie    Torgersen   NA             NA           NA
# 5   Adelie    Torgersen 36.7           19.3          193
# 6   Adelie    Torgersen 39.3           20.6          190
# 7   Adelie    Torgersen 38.9           17.8          181
# 8   Adelie    Torgersen 39.2           19.6          195
# 9   Adelie    Torgersen 34.1           18.1          193
# 10  Adelie    Torgersen 42.0           20.2          190
# 11  Adelie    Torgersen 37.8           17.1          186
# 12  Adelie    Torgersen 37.8           17.3          180
# 13  Adelie    Torgersen 41.1           17.6          182
# 14  Adelie    Torgersen 38.6           21.2          191
# 15  Adelie    Torgersen 34.6           21.1          198
# ...

# %% [markdown]
# Este dataframe consta de 8 columnas.
#
# `summary()` se utiliza para obtener un resumen estadístico de un objeto de datos. En este caso contamos con un conjunto de datos numéricos por lo que los datos que nos muestra son los siguientes:
# - cuartiles: Los cuartiles son medidas estadísticas utilizadas para dividir un conjunto de datos ordenados en cuatro partes iguales, cada una representando el 25% de los datos. Los cuartiles son útiles para comprender la distribución de los datos y detectar posibles valores atípicos o extremos. Además, se pueden usar para calcular el rango itercuartílico (IQR), que es la diferencia entre el tercer y el primer cuartil. El IQR es una medida de la dispersión de los datos y se utiliza en la identificación de valores atípicos.
# - media
# - mediana
# - Valor mínimo
# - Valor máximo
# - Valores nulos

# %%
summary(penguins)
# Out:
#       species          island    bill_length_mm  bill_depth_mm
#  Adelie   :152   Biscoe   :168   Min.   :32.10   Min.   :13.10
#  Chinstrap: 68   Dream    :124   1st Qu.:39.23   1st Qu.:15.60
#  Gentoo   :124   Torgersen: 52   Median :44.45   Median :17.30
#                                  Mean   :43.92   Mean   :17.15
#                                  3rd Qu.:48.50   3rd Qu.:18.70
#                                  Max.   :59.60   Max.   :21.50
#                                  NA's   :2       NA's   :2
#  flipper_length_mm  body_mass_g       sex           year
#  Min.   :172.0     Min.   :2700   female:165   Min.   :2007
#  1st Qu.:190.0     1st Qu.:3550   male  :168   1st Qu.:2007
#  Median :197.0     Median :4050   NA's  : 11   Median :2008
#  Mean   :200.9     Mean   :4202                Mean   :2008
#  3rd Qu.:213.0     3rd Qu.:4750                3rd Qu.:2009
#  Max.   :231.0     Max.   :6300                Max.   :2009
#  NA's   :2         NA's   :2

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %% [markdown]
# 1. `species`: especies de los pingüinos
# 2. `island`: isla en donde se encuentra al pingüino
# 3. `bill_length_mm`: longitud del pico en milímetros
# 4. `bill_depth_mm`: profundidad del pico en milímetros
# 5. `flipper_length_mm`: longitud de la altena de los pinguinos en milímetros
# 6. `body_mass_g`: índice de masa corporal, en gramos
# 7. `sex`: sexo del pingüino
# 8. `year`: año del registro

# %%
help(penguins)

# %% [markdown]
# ## Creando un ggplot
#
# Para crear un gráfico se comienza utilizando la función `ggplot()`, definiendo un objeto 'plot' al que se le agregarán capas (**layers**) al mismo. El primer argumento de `ggplot()` es el conjunto de datos que se usará para crear el gráfico `ggplot(data = penguins)` crea un gráfico vacio que se utilizará para mostrar los datos del conjunto `penguins`.

# %%
ggplot(data = penguins)
# Out:
# plot without title

# %% [markdown]
# El argumento `mapping` de la función `ggplot()` define como las variables del conjunto de datos se asignaran a las propiedades visuales (**aesthetics**) del gráfico.

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
  )
# Out:
# plot without title

# %%
# Definimos un objeto geometrico que nuestro gráfico usará para representar los datos
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
  ) +
    geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# ## Añadir estéticas y capas

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species)
  ) +
    geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = species)
) +
  geom_point() +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(mapping = aes(color = species)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# ## `shape` aesthetic

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(mapping = aes(color = species, shape = species)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(aes(color = species, shape = species)) +
  geom_smooth(method = "lm") +
  labs(
    title = "Body mass and flipper length",
    subtitle = "Dimensions for Adelie, Chinstrap, and Gentoo Penguins",
    x = "Flipper length (mm)", y = "Body mass (g)",
    color = "Species", shape = "Species"
  )
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(mapping = aes(color = bill_depth_mm)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# ## Visualizando distribuciones
#
# ### Variables categóricas
#
# Una variable es **categórica** si puede tomar uno o un pequeño grupo de valores.

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar()
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = fct_infreq(species))) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# ## Variables numéricas
#
# Una variable es *numérica* (o cuantitativa) si puede tomar un amplio rango de valores numéricos y si se puede sumar, restar, o tomar promedios con esos valores. Las variables numéricas pueden ser continuas o discretas.

# %%
ggplot(penguins, aes(x = body_mass_g)) +
  geom_histogram(binwidth = 200)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_bin()`).”
# plot without title

# %% [markdown]
# Esta función se utilizia para trazar una estimación de la densidad de probabilidad de un conjunto de datos. Esta función crea un gráfico de densidad suavizada que muestra la distribución de los datos en forma de una curva.

# %%
ggplot(penguins, aes(x = body_mass_g)) +
  geom_density()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_density()`).”
# plot without title

# %% [markdown]
# ## Visualizing relationships
#
# Una *boxplot* (diagrama de caja y bigotes) es un tipo de gráfico que mide la posición (cuartiles) que describen una distribución.
#
# - La *caja* indica el rango de la mitad media de los datos, una distancia conocida como rango intecuartílico (IQR), que va desde el percentil 25 hata el 75. La linea dentro de la caja muestra la mediana, el percentil 50. Esto sirve para conocer la dispersión de la distribución y si ésta es simétrica respecto a la mediana, o sesgada hacia algún lado.
# - Los puntos son observaciones que estan a más del 1.5 del rango intercuartilico (IQR). Estos puntos son conocidos como datos atípicos
# - Las lineas (bigotes) se extienden de los dos lados de la caja y llegan hasta el punto más alejado de la distribución que no es un valor atípico.

# %%
ggplot(penguins, aes(x = species, y = body_mass_g)) +
  geom_boxplot()
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_boxplot()`).”
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g, color = species)) +
  geom_density(linewidth = 0.75)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_density()`).”
# plot without title

# %%
ggplot(penguins, aes(x = body_mass_g, color = species, fill = species)) +
  geom_density(alpha = 0.5)
# Out:
# Warning message:
# “Removed 2 rows containing non-finite values (`stat_density()`).”
# plot without title

# %% [markdown]
# ## Dos variables categóricas
#
# Podemos utilizar una gráfica de barras apiladas para visualizar la relación entre dos variables categóricas.

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# Esta es una gráfica de frecuencias relativas, es más util para comparar las distribuciones de las especias a traves de las islas

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = "fill")
# Out:
# plot without title

# %% [markdown]
# ## Tres o más variables numericas

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
  geom_point(aes(color = species, shape = island))
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title

# %% [markdown]
# No es recomendable agregar muchas estéticas a un gráfico porque se hace dificil de leer. Otra función útil para las variables categóricas es dividir el gráfico en '*facets*'

# %%
ggplot(penguins, aes(x = flipper_length_mm, y = body_mass_g)) +
  geom_point(aes(color = species, shape = species)) +
  facet_wrap(~island)
# Out:
# Warning message:
# “Removed 2 rows containing missing values (`geom_point()`).”
# plot without title
